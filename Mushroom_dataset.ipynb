# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
#Problem statement
#Mushroom dataset is object type dataset which to be changed to numric
#so as to estimate which type of mushroom would be edible or nonedible.

# %%
df=pd.read_csv("Mushroom_dataset")
df.head(10)
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
# 5    e         x           y         y       t    a               f
# 6    e         b           s         w       t    a               f
# 7    e         b           y         w       t    l               f
# 8    p         x           y         w       t    p               f
# 9    e         b           s         y       t    a               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %%
#first five details of the mushroom data_set

# %%
df.shape
# Out:
# (8124, 23)

# %%
#the dataset has 8124 rows and 23 columns

# %%
#Attribute Information: 

#(classes: edible=e, poisonous=p)

#cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s

#cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s

#cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y

#bruises: bruises=t,no=f

#odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s

#gill-attachment: attached=a,descending=d,free=f,notched=n

#gill-spacing: close=c,crowded=w,distant=d

#gill-size: broad=b,narrow=n

#gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y

#stalk-shape: enlarging=e,tapering=t

#stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?

#stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s

#stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s

#stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y

#stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y

#veil-type: partial=p,universal=u

#veil-color: brown=n,orange=o,white=w,yellow=y
    
#ring-number: none=n,one=o,two=t

#ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z

#spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y

#population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y

#habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      8124 non-null   object
#  1   cap_shape                 8124 non-null   object
#  2   cap_surface               8124 non-null   object
#  3   cap_color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill_attachment           8124 non-null   object
#  7   gill_spacing              8124 non-null   object
#  8   gill_size                 8124 non-null   object
#  9   gill_color                8124 non-null   object
#  10  stalk_shape               8124 non-null   object
#  11  stalk_root                8124 non-null   object
#  12  stalk_surface_above_ring  8124 non-null   object
# ...

# %%
#the dataset is all object type
#23 columns and 8124 rows

# %%
df.isnull().sum()
# Out:
# type                        0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#There is no null values in the dataset

# %%
df.dtypes
# Out:
# type                        object
# cap_shape                   object
# cap_surface                 object
# cap_color                   object
# bruises                     object
# odor                        object
# gill_attachment             object
# gill_spacing                object
# gill_size                   object
# gill_color                  object
# stalk_shape                 object
# stalk_root                  object
# stalk_surface_above_ring    object
# stalk_surface_below_ring    object
# stalk_color_above_ring      object
# stalk_color_below_ring      object
# veil_type                   object
# veil_color                  object
# ring_number                 object
# ring_type                   object
# spore_print_color           object
# population                  object
# habitat                     object
# dtype: object

# %%
#The dataset has object datatype

# %%
sns.heatmap(df.isnull())

# %%
#Projecting the null dataset in heatmap

# %%
sns.countplot(df['type'])

# %%
#Edible mushrooms are more compared to poisonous mushrooms

# %%
sns.scatterplot(x="type",y="cap_shape",data=df)

# %%
#Edible and non-edible has more or less similar shapes
#shape-wise not much differences
# 0 is edible 
#1 is eidble

# %%
sns.scatterplot(x="type",y="cap_color",data=df)

# %%
#Edible mushrooms(0) are uniformly coloured rather to poisonous.
#Poisonous mushrooms(1) lack inbetween (6-8)

# %%
sns.scatterplot(x="type",y="odor",data=df)

# %%
#Mojority of edible mushrooms have almond and pungent oder, while unedible are more have different types of oder

# %%
plt.figure(figsize = (14,6))
g = sns.catplot(x="cap_shape", hue="cap_color", col="type",data=df, kind="count",height=8, aspect=.7)

# %%
#edible mushoorms have higest purple colour,rest majority being=red,green,blue
#Poisionous mushrooms have highest as red, rest majority being purple,green,blue

# %%
g = sns.catplot(x="odor", hue="bruises", col="type",data=df, kind="count",height=8, aspect=.7 , palette = 'inferno')

# %%
#Edible mushrooms have bruises while poisonous non-bruises

# %%
le = LabelEncoder()
df=df.apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    type  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0     1          5            2          4        1     6                1
# 1     0          5            2          9        1     0                1
# 2     0          0            2          8        1     3                1
# 3     1          5            3          8        1     6                1
# 4     0          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color  ...  stalk_surface_below_ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  \
# ...

# %%
#Converting the entire dataset into numeric for evaluation

# %%
dfcor=df.corr()
dfcor
# Out:
#                               type  cap_shape  cap_surface  cap_color  \
# type                      1.000000   0.052951     0.178446  -0.031384
# cap_shape                 0.052951   1.000000    -0.050454  -0.048203
# cap_surface               0.178446  -0.050454     1.000000  -0.019402
# cap_color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill_attachment           0.129200   0.078865    -0.034180   0.041436
# gill_spacing             -0.348387   0.013196    -0.282306   0.144259
# gill_size                 0.540024   0.054050     0.208100  -0.169464
# gill_color               -0.530566  -0.006039    -0.161017   0.084659
# stalk_shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk_root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(dfcor,annot=True,linewidth=0.5,linecolor="black",fmt=".2f")

# %%
#From the above results it is clear that some columns are positively correlated with type while some are not.

#Positively correlated:-
#Gill-size is highly correlated, while some other positively correlated columns are cap_shape,cap_surface,gill_attachment,spore_print_color
#population,habitat

#Some Negatively corrleated columns:-
#Bruises,gill_spacing, gill_color, stalk_shape, stalk_root, stalk_surface_above_ring, stalk_surface_below_ring

# %%
df.describe()
# Out:
#               type    cap_shape  cap_surface    cap_color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill_attachment  gill_spacing    gill_size   gill_color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
#There are 8 rows and 23 columns
#total count is 8124
#Dataset is widely dispersed(#significance difference between mean and median)

# %%
#Checking the outliers

# %%
df.plot(kind='box',subplots=True,layout=(4,7),fontsize=1)
# Out:
# type                            AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# cap_shape                    AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# cap_surface                  AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# cap_color                    AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# bruises                      AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# odor                         AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# gill_attachment              AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# gill_spacing                   AxesSubplot(0.125,0.518913;0.0945122x0.16413)
# gill_size                   AxesSubplot(0.238415,0.518913;0.0945122x0.16413)
# gill_color                  AxesSubplot(0.351829,0.518913;0.0945122x0.16413)
# stalk_shape                 AxesSubplot(0.465244,0.518913;0.0945122x0.16413)
# stalk_root                  AxesSubplot(0.578659,0.518913;0.0945122x0.16413)
# ...

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
df.plot.box(figsize=(12,7), xticks=[])
plt.title('Boxplots of all frequency bins')
plt.xlabel('Frequency bin')
plt.ylabel('Power spectral density (normalized)')
plt.show()

# %%
df.skew()
# Out:
# type                        0.071946
# cap_shape                  -0.247052
# cap_surface                -0.590859
# cap_color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill_attachment            -5.977076
# gill_spacing                1.840088
# gill_size                   0.825797
# gill_color                  0.061410
# stalk_shape                -0.271345
# stalk_root                  0.947852
# stalk_surface_above_ring   -1.098739
# stalk_surface_below_ring   -0.757703
# stalk_color_above_ring     -1.835434
# stalk_color_below_ring     -1.791593
# veil_type                   0.000000
# veil_color                 -6.946944
# ring_number                 2.701657
# ring_type                  -0.290018
# spore_print_color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %%
#standard skewness threshold is taken as +/0.50
#cap_surface,gill_attachment,stalk_surface_above_ring,stalk_surface_below_ring,veil_color,
#stalk_color_above_ring,stalk_surface_below_ring,veil_color,population are highly negatively skewed
#cap_color,gill_spacing,gill_size,stalk_root,ring_number,spore_print_color are some positively skewed

# %%
df.hist(sharex=False, sharey=False, xlabelsize=1, ylabelsize=1, figsize=(12,12))
plt.show()

# %%
#before removing skewness
#The dataset is skewed

# %%
df['gill_attachment'].plot.hist("gill_attachment")

# %%
#The dataset is negatively skewed in comparison to poisonous mushrooms

# %%
df['veil_color'].plot.hist("veil_color")

# %%
sns.distplot(df["stalk_surface_above_ring"])

# %%
sns.distplot(df["gill_spacing"])

# %%
sns.distplot(df["ring_number"])

# %%
x=df.iloc[:,1:]
x.head()
# Out:
#    cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk_surface_below_ring  stalk_color_above_ring  stalk_color_below_ring  \
# 0                         2                       7                       7
# ...

# %%
y=df.iloc[:,:1]
y.head()
# Out:
#    type
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0

# %%
#type(y) being the target,rest being the colums

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method="yeo-johnson")

# %%
x
# Out:
# array([[ 1.03577474,  0.05017017, -0.02673986, ..., -0.53714841,
#         -0.80052972,  1.51548871],
#        [ 1.03577474,  0.05017017,  1.56319371, ...,  0.01906382,
#         -1.47485647,  0.11634762],
#        [-2.02788189,  0.05017017,  1.30592999, ...,  0.01906382,
#         -1.47485647,  1.06633941],
#        ...,
#        [-0.85127533,  0.05017017, -0.02673986, ..., -2.80619461,
#         -1.89857525,  0.70247929],
#        [-0.23408877,  0.99864626, -0.02673986, ...,  1.29862534,
#          0.15412432,  0.70247929],
#        [ 1.03577474,  0.05017017, -0.02673986, ...,  0.4401869 ,
#         -1.89857525,  0.70247929]])

# %%
#removing skewness by transforming data

# %%
#to check the outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (8124, 23)

# %%
#making entire dataset positive after zscore
#8124 rows and 23 cols.

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([1816, 2128, 2128, ..., 8121, 8123, 8123], dtype=int64), array([15, 14, 15, ..., 17,  6, 17], dtype=int64))

# %%
z[1816][15]
# Out:
# 3.0383605317184252

# %%
z[2128][14]
# Out:
# 3.058610708783329

# %%
# apply ye0-johnson method after removing the extreme values
#i did that before, but was showing the same
# applied outlier and then skewed
# please raise a ticket for this
i have raised
one min

# %%
for i in df.columns:
    tempDF = df.drop(i, axis=1)
    for j in tempDF.columns:
        NewDF = tempDF.drop(j, axis=1)
        newDF = NewDF[(z<3).all(axis=1)]
        print(newDF.shape,i,j)
    # there might be two columns
# Out:
# (0, 21) type cap_shape
# (0, 21) type cap_surface
# (0, 21) type cap_color
# (0, 21) type bruises
# (0, 21) type odor
# (0, 21) type gill_attachment
# (0, 21) type gill_spacing
# (0, 21) type gill_size
# (0, 21) type gill_color
# (0, 21) type stalk_shape
# (0, 21) type stalk_root
# (0, 21) type stalk_surface_above_ring
# (0, 21) type stalk_surface_below_ring
# (0, 21) type stalk_color_above_ring
# (0, 21) type stalk_color_below_ring
# (0, 21) type veil_type
# (0, 21) type veil_color
# (0, 21) type ring_number
# (0, 21) type ring_type
# (0, 21) type spore_print_color
# (0, 21) type population
# (0, 21) type habitat
# (0, 21) cap_shape type
# (0, 21) cap_shape cap_surface
# (0, 21) cap_shape cap_color
# (0, 21) cap_shape bruises
# (0, 21) cap_shape odor
# (0, 21) cap_shape gill_attachment
# (0, 21) cap_shape gill_spacing
# (0, 21) cap_shape gill_size
# (0, 21) cap_shape gill_color
# (0, 21) cap_shape stalk_shape
# (0, 21) cap_shape stalk_root
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (8124, 23)
# (0, 23)

# %%
#as all the row values are above 3 and none below 3, we are not implementing zscore
#The data by nature is widely disbursed

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.03577474,  0.05017017, -0.02673986, ..., -0.53714841,
#         -0.80052972,  1.51548871],
#        [ 1.03577474,  0.05017017,  1.56319371, ...,  0.01906382,
#         -1.47485647,  0.11634762],
#        [-2.02788189,  0.05017017,  1.30592999, ...,  0.01906382,
#         -1.47485647,  1.06633941],
#        ...,
#        [-0.85127533,  0.05017017, -0.02673986, ..., -2.80619461,
#         -1.89857525,  0.70247929],
#        [-0.23408877,  0.99864626, -0.02673986, ...,  1.29862534,
#          0.15412432,  0.70247929],
#        [ 1.03577474,  0.05017017, -0.02673986, ...,  0.4401869 ,
#         -1.89857525,  0.70247929]])

# %%
#Standardising the dataset

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
lg=LogisticRegression()

# %%
#LogisticRegression used as y is only two(edible or non-edible(yes/no)) and repsective matrix also called for the test

# %%
from sklearn.model_selection import train_test_split
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lg.fit(x_train,y_train)
    pred_train=lg.predict(x_train)
    pred_test=lg.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,2)==round(accuracy_score(y_test,pred_test)*100,2):
        print("At random state",i,"The model performs very well")
        print("At random state:-",i)
        print("Training accuracy_score:-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy_score:-",accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 53 The model performs very well
# At random state:- 53
# Training accuracy_score:- 94.8915217725804
# Testing accuracy_score:- 94.89230769230768
# At random state 139 The model performs very well
# At random state:- 139
# Training accuracy_score:- 95.32235728573627
# Testing accuracy_score:- 95.32307692307693
# At random state 288 The model performs very well
# At random state:- 288
# Training accuracy_score:- 95.13771349438375
# Testing accuracy_score:- 95.13846153846154
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-322-df1212fc2477> in <module>
#       2 for i in range(0,1000):
#       3     x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
# ----> 4     lg.fit(x_train,y_train)
#       5     pred_train=lg.predict(x_train)
#       6     pred_test=lg.predict(x_test)
#
# ...

# %%
#we will use random state 139

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=139)

# %%
print(classification_report(y_test,pred_test))

# %%
x_test.dtype
# Out:
# dtype('float64')

# %%
y_test
# Out:
#       type
# 3296     0
# 8101     1
# 5367     1
# 7063     0
# 6337     1
# ...    ...
# 4328     1
# 5532     1
# 6908     1
# 4368     1
# 482      0
#
# [1625 rows x 1 columns]

# %%
#precision & fi-score is almost similar but not a very good score

# %%
pred_lg=lg.predict(x_test)
from sklearn.model_selection import cross_val_score
lss= accuracy_score(y_test,pred_lg)
for j in range(2,10):
    lsscore= cross_val_score(lg,x,y,cv=j)
    lsc= lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("accuracy score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 78.53274249138356
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 3
# Cross validation score is:- 80.25603151157065
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 4
# Cross validation score is:- 83.13638601674052
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 5
# Cross validation score is:- 81.81541492989768
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 6
# Cross validation score is:- 84.55194485475135
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 7
# Cross validation score is:- 85.1422885825452
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 8
# Cross validation score is:- 84.44020063224855
# accuracy score is:- 95.32307692307693
#
#
# At cv:- 9
# Cross validation score is:- 87.32031712746404
# accuracy score is:- 95.32307692307693

# %%
#Hyper-tuning the dataset with cross_val_score,accuracy score and Auc Roc curve

# %%
#Since cross validation score accuracy score are almost same.We are heading with a good approach

# %%
lsscore_selected = cross_val_score(lg,x,y,cv=9).mean()
print("The cv score is:",lsscore_selected,"\nThe accuracy score is:",lss)
# Out:
# The cv score is: 0.8732031712746404
# The accuracy score is: 0.9538461538461539

# %%
#Accuracy score is better than CV score

# %%
#AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds =roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)

# %%
plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve(area = %0.2f)'%roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristics')
plt.legend(loc="lower right")
plt.show()

# %%
import pickle
filename='Mushroom_dataset.pkl'
pickle.dump(lg,open(filename,'wb'))

# %%
y_test.reset_index(drop = True, inplace = True)

# %%
y.shape, predicted.shape
# Out:
# ((8124, 1), (1625,))

# %%
lg.fit(x_train,y_train)
predicted=lg.predict(x_test)
PredDF=pd.DataFrame({"Predicted":predicted,"Original":y_test.values.flatten()})
PredDF
# Out:
#       Predicted  Original
# 0             0         0
# 1             1         1
# 2             1         1
# 3             0         0
# 4             1         1
# ...         ...       ...
# 1620          1         1
# 1621          1         1
# 1622          1         1
# 1623          1         1
# 1624          0         0
#
# [1625 rows x 2 columns]

# %%
#PredDF# it was harder than I thought :)thank you so much
#one min

# %%
y_test.shape
# Out:
# (1625, 1)

# %%
predicted.shape
# Out:
# (1625,)

# %%
y_test.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-347-d8dc54734212> in <module>
# ----> 1 y_test.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
